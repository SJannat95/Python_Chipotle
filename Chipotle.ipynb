# %% [markdown]
# <a href="https://colab.research.google.com/github/SJannat95/Python_Chipotle/blob/main/Chipotle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/SJannat95/Python_Chipotle/main/Chipotle.csv"
Chipotle= pd.read_csv(url)
Chipotle.head(3)
# Out:
#         top1 wordofmouth socialmedia walkby billboard  patronage  \
# 0  Applebees         Yes          No     No        No          0
# 1      Arbys         Yes          No     No        No          0
# 2      Arbys          No          No    Yes        No          0
#
#    importantconvenience  importantvariety  importantprice  importanthealthy  \
# 0                   4.0               4.0             5.0               4.0
# 1                   4.0               4.0             4.0               4.0
# 2                   3.0               4.0             4.0               4.0
#
#    ...  chipotlehealthy  chipotletaste  chipotleambience  gender   age  \
# 0  ...              5.0            5.0               5.0    Male  51.0
# 1  ...              5.0            5.0               5.0    Male  51.0
# 2  ...              4.0            5.0               5.0  Female  51.0
#
#     income  plan  spending buylocal  healthyimportanttome
# ...

# %%
Chipotle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   top1                  357 non-null    object
#  1   wordofmouth           357 non-null    object
#  2   socialmedia           357 non-null    object
#  3   walkby                357 non-null    object
#  4   billboard             357 non-null    object
#  5   patronage             357 non-null    int64
#  6   importantconvenience  338 non-null    float64
#  7   importantvariety      333 non-null    float64
#  8   importantprice        334 non-null    float64
#  9   importanthealthy      335 non-null    float64
#  10  importanttaste        332 non-null    float64
#  11  importantambience     335 non-null    float64
#  12  chipotleconvenient    334 non-null    float64
#  13  chipotlevariety       333 non-null    float64
# ...

# %%
Chipotle['top1'].value_counts()
# Out:
# In-n-out         76
# El Pollo Loco    57
# Panera           50
# Chipotle         42
# Subway           40
# Chick-Fil-A      33
# KFC              25
# McDonalds        17
# Arbys             3
# Starbucks         2
# Wendy's           2
# Jasons Deli       2
# Outback           1
# Pizza express     1
# Pizza Hut         1
# Eppies            1
# Burger King       1
# Taco Bell         1
# The Market        1
# Applebees         1
# Name: top1, dtype: int64

# %%
Chipotle['top1'].describe()
# Out:
# count          357
# unique          20
# top       In-n-out
# freq            76
# Name: top1, dtype: object

# %%
Chipotle['gender'].describe()
# Out:
# count      343
# unique       2
# top       Male
# freq       271
# Name: gender, dtype: object

# %%
print(Chipotle.corr())
# Out:
#                       patronage  importantconvenience  importantvariety  \
# patronage              1.000000             -0.184009         -0.089479
# importantconvenience  -0.184009              1.000000          0.379041
# importantvariety      -0.089479              0.379041          1.000000
# importantprice        -0.031176              0.219773          0.358237
# importanthealthy      -0.194962              0.177598          0.331164
# importanttaste        -0.020958              0.022364          0.093630
# importantambience     -0.186999              0.191377          0.375228
# chipotleconvenient    -0.142545              0.192236          0.096802
# chipotlevariety       -0.015089              0.093584          0.360278
# chipotleprice         -0.015940              0.128264          0.282238
# chipotlehealthy       -0.078458              0.137211          0.131349
# chipotletaste         -0.054768              0.143569          0.103151
# ...

# %%
importance = Chipotle.iloc[:,7:12]
correlations = importance.corr(method='pearson')
plt.figure(figsize=(15, 12))
sns.heatmap(correlations, cmap="coolwarm", annot=True)
plt.show()

# %%
sns.scatterplot(data=Chipotle, x='age', y='income', hue='gender')

# %%
plt.figure(figsize=(16, 12))
sns.histplot(x="top1", hue="gender", data=Chipotle)
plt.show()

# %%
Chipotle3=Chipotle.loc[(Chipotle['top1'] == 'Chipotle') & (Chipotle['patronage']> 0)]
Chipotle3.head(3)
# Out:
#         top1 wordofmouth socialmedia walkby billboard  patronage  \
# 44  Chipotle          No          No     No        No          1
# 47  Chipotle         Yes          No     No        No          3
# 52  Chipotle          No          No    Yes        No          4
#
#     importantconvenience  importantvariety  importantprice  importanthealthy  \
# 44                   5.0               4.0             5.0               5.0
# 47                   5.0               5.0             5.0               4.0
# 52                   5.0               4.0             5.0               3.0
#
#     ...  chipotlehealthy  chipotletaste  chipotleambience  gender   age  \
# 44  ...              5.0            5.0               4.0    Male  24.0
# 47  ...              5.0            3.0               3.0    Male  38.0
# 52  ...              4.0            5.0               5.0    Male  19.0
#
#      income  plan  spending buylocal  healthyimportanttome
# ...

# %%
Chipotle4=Chipotle.loc[(Chipotle['top1'] == 'In-n-out') & (Chipotle['patronage']> 0)]
Chipotle4.head(3)
# Out:
#          top1 wordofmouth socialmedia walkby billboard  patronage  \
# 140  In-n-out         Yes          No     No        No          2
# 142  In-n-out         Yes          No     No        No          3
# 154  In-n-out         Yes          No     No        No          4
#
#      importantconvenience  importantvariety  importantprice  importanthealthy  \
# 140                   4.0               4.0             5.0               4.0
# 142                   5.0               3.0             4.0               5.0
# 154                   4.0               3.0             4.0               3.0
#
#      ...  chipotlehealthy  chipotletaste  chipotleambience  gender   age  \
# 140  ...              4.0            4.0               4.0  Female  69.0
# 142  ...              5.0            5.0               3.0    Male  58.0
# 154  ...              3.0            3.0               3.0    Male  58.0
#
#       income  plan  spending buylocal  healthyimportanttome
# ...

# %%
Chipotle3.loc[:,['top1','gender','patronage']].head(3)
# Out:
#         top1 gender  patronage
# 44  Chipotle   Male          1
# 47  Chipotle   Male          3
# 52  Chipotle   Male          4

# %%
Chipotle4.loc[:,['top1','gender','patronage']].head(3)
# Out:
#          top1  gender  patronage
# 140  In-n-out  Female          2
# 142  In-n-out    Male          3
# 154  In-n-out    Male          4

# %%
plt.figure(figsize=(14, 10))
sns.barplot(
    x="wordofmouth", 
    y="patronage", 
    data=Chipotle3, 
    ci=None,  
    hue='wordofmouth', color='purple');

# %%
plt.figure(figsize=(14, 10))
sns.barplot(
    x="socialmedia", 
    y="patronage", 
    data=Chipotle3, 
    ci=None,  
    hue='socialmedia', color='green');

# %%
plt.figure(figsize=(14, 10))
sns.barplot(
    x="walkby", 
    y="patronage", 
    data=Chipotle3, 
    ci=None,  
    hue='walkby', color='green');

# %%
plt.figure(figsize=(14, 10))
sns.barplot(
    x="billboard", 
    y="patronage", 
    data=Chipotle3, 
    ci=None,  
    hue='billboard', color='green');
